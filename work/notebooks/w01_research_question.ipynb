# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/vedant08mehta/Flyrank-assignment1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# Unnamed Lane: Content performance and decline detection. I want to investigate which content pages show signs of underperformance despite receiving meaningful search exposure, and whether measurable signals such as impressions, clicks, CTR, position, and content characteristics can help identify pages worth reviewing. I chose this lane because the initial dataset exploration showed that some pages receive substantial impressions without generating clicks, suggesting there may be useful patterns to investigate over the following weeks.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# The decision is which pages should be prioritized for content review or further investigation. A content or SEO team could use the analysis to focus limited review time on pages showing stronger evidence of underperformance rather than treating every page equally. A false positive could waste time on a page that does not need intervention, while a false negative could cause a genuinely underperforming page to be missed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# !git clone https://github.com/vedant08mehta/Flyrank-assignment1.git
# Out:
# Cloning into 'Flyrank-assignment1'...
# remote: Enumerating objects: 126, done.
# remote: Counting objects: 100% (126/126), done.
# remote: Compressing objects: 100% (82/82), done.
# remote: Total 126 (delta 37), reused 96 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (126/126), 1.87 MiB | 7.35 MiB/s, done.
# Resolving deltas: 100% (37/37), done.

# %%
# %cd /content/Flyrank-assignment1
# Out:
# /content/Flyrank-assignment1

# %%
import os

print(os.path.exists("data/raw/content_refresh_anonymized.csv"))
# Out:
# True

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print(f"Total pages: {len(df):,}")

zero_clicks = df.loc[
    (df["impressions_90d"] >= 100) &
    (df["clicks_90d"] == 0)
]

print(
    f"Pages with 100+ impressions and 0 clicks: "
    f"{len(zero_clicks):,}"
)

print(
    f"Share of all pages in this group: "
    f"{len(zero_clicks) / len(df) * 100:.1f}%"
)
# Out:
# Total pages: 30,000
# Pages with 100+ impressions and 0 clicks: 6,068
# Share of all pages in this group: 20.2%

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# This work will provide observed and directional evidence about which measurable content and search-performance signals are associated with underperformance. It can support prioritization and decision-making about which pages deserve further investigation. It cannot establish that any particular factor causes a change in performance, prove how Google's algorithm works, or guarantee that a page will gain or lose traffic as a result of an intervention.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
